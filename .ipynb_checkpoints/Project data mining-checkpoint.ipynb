# %% [markdown]
# ## Alcohol and students
# Data source: https://www.kaggle.com/datasets/uciml/student-alcohol-consumption?resource=download

# %%
import pandas as pd

mat_df = pd.read_csv('student-mat.csv')
por_df = pd.read_csv('student-por.csv')

# %% [markdown]
# ## Remove unrelevant attributes and rename grade attribute

# %%
por_df = por_df.drop(columns=['school', 'famsize', 'famsup', 'Medu', 'Fedu', 'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'schoolsup', 'paid', 'nursery', 'internet', 'G1', 'G2'])
por_df = por_df.rename(columns = {'G3':'grade'})

mat_df = mat_df.drop(columns=['school', 'famsize', 'famsup', 'Medu', 'Fedu', 'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'schoolsup', 'paid', 'nursery', 'internet', 'G1', 'G2'])
mat_df = mat_df.rename(columns = {'G3':'grade'})

# %%
print(por_df)
print(mat_df)
# Out:
#     sex  age address Pstatus  studytime  failures activities higher romantic  \
# 0     F   18       U       A          2         0         no    yes       no
# 1     F   17       U       T          2         0         no    yes       no
# 2     F   15       U       T          2         0         no    yes       no
# 3     F   15       U       T          3         0        yes    yes      yes
# 4     F   16       U       T          2         0         no    yes       no
# ..   ..  ...     ...     ...        ...       ...        ...    ...      ...
# 644   F   19       R       T          3         1        yes    yes       no
# 645   F   18       U       T          2         0         no    yes       no
# 646   F   18       U       T          2         0        yes    yes       no
# 647   M   17       U       T          1         0         no    yes       no
# 648   M   18       R       T          1         0         no    yes       no
#
#      famrel  freetime  goout  Dalc  Walc  health  absences  grade
# 0         4         3      4     1     1       3         4     11
# 1         5         3      3     1     1       3         2     11
# 2         4         3      2     2     3       3         6     12
# 3         3         2      2     1     1       5         0     14
# 4         4         3      2     1     2       5         0     13
# ..      ...       ...    ...   ...   ...     ...       ...    ...
# 644       5         4      2     1     2       5         4     10
# 645       4         3      4     1     1       1         4     16
# 646       1         1      1     1     1       5         6      9
# 647       2         4      5     3     4       2         6     10
# 648       4         4      1     3     4       5         4     11
#
# [649 rows x 17 columns]
#     sex  age address Pstatus  studytime  failures activities higher romantic  \
# 0     F   18       U       A          2         0         no    yes       no
# 1     F   17       U       T          2         0         no    yes       no
# 2     F   15       U       T          2         3         no    yes       no
# 3     F   15       U       T          3         0        yes    yes      yes
# 4     F   16       U       T          2         0         no    yes       no
# ..   ..  ...     ...     ...        ...       ...        ...    ...      ...
# 390   M   20       U       A          2         2         no    yes       no
# 391   M   17       U       T          1         0         no    yes       no
# 392   M   21       R       T          1         3         no    yes       no
# 393   M   18       R       T          1         0         no    yes       no
# 394   M   19       U       T          1         0         no    yes       no
#
#      famrel  freetime  goout  Dalc  Walc  health  absences  grade
# 0         4         3      4     1     1       3         6      6
# 1         5         3      3     1     1       3         4      6
# 2         4         3      2     2     3       3        10     10
# 3         3         2      2     1     1       5         2     15
# 4         4         3      2     1     2       5         4     10
# ..      ...       ...    ...   ...   ...     ...       ...    ...
# 390       5         5      4     4     5       4        11      9
# 391       2         4      5     3     4       2         3     16
# 392       5         5      3     3     3       3         3      7
# 393       4         4      1     3     4       5         0     10
# 394       3         2      3     3     3       5         5      9
#
# [395 rows x 17 columns]

# %%
mat_df.corr()
# Out:
#                 age  studytime  failures    famrel  freetime     goout  \
