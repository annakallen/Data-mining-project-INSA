# %% [markdown]
# ## Preprocessing and clustering of a breat cancer dataset
#
# Dataset source: https://www.kaggle.com/code/jyotsanakunwer/breast-cancer-classification-95-9-accuracy/data

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("data.csv")
data = data.drop(columns = ['Unnamed: 32', 'id'])

# %%
data
# Out:
#     diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0           M        17.99         10.38          122.80     1001.0
# 1           M        20.57         17.77          132.90     1326.0
# 2           M        19.69         21.25          130.00     1203.0
# 3           M        11.42         20.38           77.58      386.1
# 4           M        20.29         14.34          135.10     1297.0
# ..        ...          ...           ...             ...        ...
# 564         M        21.56         22.39          142.00     1479.0
# 565         M        20.13         28.25          131.20     1261.0
# 566         M        16.60         28.08          108.30      858.1
# 567         M        20.60         29.33          140.10     1265.0
# 568         B         7.76         24.54           47.92      181.0
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# ...

# %% [markdown]
# Next, a correlation matrix was used to evaluate the clusterability of the data set.

# %%
data['diagnosis']=(data['diagnosis']=='M').astype(int) #changed value from categorical to int to be able to get the confusion matrix
data.corr()
# Out:
#                          diagnosis  radius_mean  texture_mean  perimeter_mean  \
# diagnosis                 1.000000     0.730029      0.415185        0.742636
# radius_mean               0.730029     1.000000      0.323782        0.997855
# texture_mean              0.415185     0.323782      1.000000        0.329533
# perimeter_mean            0.742636     0.997855      0.329533        1.000000
# area_mean                 0.708984     0.987357      0.321086        0.986507
# smoothness_mean           0.358560     0.170581     -0.023389        0.207278
# compactness_mean          0.596534     0.506124      0.236702        0.556936
# concavity_mean            0.696360     0.676764      0.302418        0.716136
# concave points_mean       0.776614     0.822529      0.293464        0.850977
# symmetry_mean             0.330499     0.147741      0.071401        0.183027
# fractal_dimension_mean   -0.012838    -0.311631     -0.076437       -0.261477
# ...

# %% [markdown]
# The columns dropped next were observed to have exceedingly high correlations with other attributes, so they were dropped under the assumption that not much information would be lost. Furthermore, this helped to alleviate the curse of dimensionality by reducing it.

# %%
data = data.drop(columns = {'perimeter_mean', 'area_mean', 'radius_worst', 'perimeter_worst', 'area_worst'})
data.corr()
# Out:
#                          diagnosis  radius_mean  texture_mean  \
# diagnosis                 1.000000     0.730029      0.415185
# radius_mean               0.730029     1.000000      0.323782
# texture_mean              0.415185     0.323782      1.000000
# smoothness_mean           0.358560     0.170581     -0.023389
# compactness_mean          0.596534     0.506124      0.236702
# concavity_mean            0.696360     0.676764      0.302418
# concave points_mean       0.776614     0.822529      0.293464
# symmetry_mean             0.330499     0.147741      0.071401
# fractal_dimension_mean   -0.012838    -0.311631     -0.076437
# radius_se                 0.567134     0.679090      0.275869
# texture_se               -0.008303    -0.097317      0.386358
# perimeter_se              0.556141     0.674172      0.281673
# area_se                   0.548236     0.735864      0.259845
# smoothness_se            -0.067016    -0.222600      0.006614
# ...

# %% [markdown]
# Next, as the data would be expected to cluster into two groups (malignant and benign diagnoses), statistical properties of each assumed cluster were evaluated to determine their separability. The values from the different classes are very separable, which implies that the datset probably is clusterable.

# %%
mask = data['diagnosis'] == 1
data_m = data[mask]
data_b = data[~mask]

# %%
data_m.describe()
# Out:
#        diagnosis  radius_mean  texture_mean  smoothness_mean  \
# count      212.0   212.000000    212.000000       212.000000
# mean         1.0    17.462830     21.604906         0.102898
# std          0.0     3.203971      3.779470         0.012608
# min          1.0    10.950000     10.380000         0.073710
# 25%          1.0    15.075000     19.327500         0.094010
# 50%          1.0    17.325000     21.460000         0.102200
# 75%          1.0    19.590000     23.765000         0.110925
# max          1.0    28.110000     39.280000         0.144700
#
#        compactness_mean  concavity_mean  concave points_mean  symmetry_mean  \
# count        212.000000      212.000000           212.000000     212.000000
# mean           0.145188        0.160775             0.087990       0.192909
# std            0.053987        0.075019             0.034374       0.027638
# min            0.046050        0.023980             0.020310       0.130800
# ...

# %%
data_b.describe()
# Out:
#        diagnosis  radius_mean  texture_mean  smoothness_mean  \
# count      357.0   357.000000    357.000000       357.000000
# mean         0.0    12.146524     17.914762         0.092478
# std          0.0     1.780512      3.995125         0.013446
# min          0.0     6.981000      9.710000         0.052630
# 25%          0.0    11.080000     15.150000         0.083060
# 50%          0.0    12.200000     17.390000         0.090760
# 75%          0.0    13.370000     19.760000         0.100700
# max          0.0    17.850000     33.810000         0.163400
#
#        compactness_mean  concavity_mean  concave points_mean  symmetry_mean  \
# count        357.000000      357.000000           357.000000     357.000000
# mean           0.080085        0.046058             0.025717       0.174186
# std            0.033750        0.043442             0.015909       0.024807
# min            0.019380        0.000000             0.000000       0.106000
# ...

# %% [markdown]
# To get to know out data better, we plotted historgrams for all of the attributes. We can conclude that the class balance is quite good, but there are a few outliers.

# %%
data.hist(figsize=(40,40), bins=27)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x00000220A1F67808>,
# ...
#       dtype=object)

# %% [markdown]
# The next step was t0 handle the outliers to achieve better clustering.

# %%
def set_to_mean(row, bin_name, col, frame):
    meaned_values = []
    bin_interval = row[bin_name]
    for val in frame[col]:
        if val in bin_interval:
            meaned_values.append(val)
    row[col] = np.mean(meaned_values)
    return row

processed_data = data.drop(columns = ['diagnosis'])
columns = processed_data.columns
drop_columns = []
for col in columns:
    bin_name = 'bin_' + col
    processed_data[bin_name] = pd.qcut(processed_data[col], q=10, precision=5)
    drop_columns.append(bin_name)
for col in columns:
    bin_name = 'bin_' + col
    processed_data = processed_data.apply(lambda f: set_to_mean(f, bin_name, col, data2), axis=1)
processed_data = processed_data.drop(columns = drop_columns)
processed_data
# Out:
#      radius_mean  texture_mean  smoothness_mean  compactness_mean  \
# 0      18.324483     12.804035         0.122521          0.219140
# 1      21.453750     17.354821         0.086125          0.075380
# 2      21.453750     20.553860         0.110893          0.157588
# 3      11.691754     20.553860         0.122521          0.219140
# 4      21.453750     14.920175         0.101166          0.130484
# ..           ...           ...              ...               ...
# 564    21.453750     21.816034         0.110893          0.114774
# 565    21.453750     27.803158         0.097707          0.101148
# 566    15.914561     27.803158         0.086125          0.101148
# 567    21.453750     27.803158         0.122521          0.219140
# 568     9.342052     23.718214         0.074103          0.040022
#
#      concavity_mean  concave points_mean  symmetry_mean  \
# 0          0.265454             0.132232       0.235960
# 1          0.099248             0.073251       0.182196
# ...

# %%
processed_data.hist(figsize=(40, 40), bins = 30)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x00000220AAA06448>,
# ...
#       dtype=object)

# %%
ground_truth = data

# %% [markdown]
# While the algorithm used is multi-dimensional, the columns 'radius_mean' and 'concave points_mean' are displayed as two of the attributes under consideration. If two groups emerge successfully, it is an indicator that these attributes in tandem correlates with the class of each object.

# %%
from sklearn import cluster
k_means = cluster.KMeans(n_clusters=2, max_iter=20000, random_state=1)
k_means.fit(processed_data)

labels = pd.DataFrame(k_means.labels_,columns=['Cluster ID'])
result = pd.concat((data,labels), axis=1)
result.plot.scatter(x='radius_mean',y='concave points_mean',c='Cluster ID', colormap='jet')

# %%
centroids = k_means.cluster_centers_
pd.DataFrame(centroids,columns=processed_data.columns)
# Out:
#    radius_mean  texture_mean  smoothness_mean  compactness_mean  \
# 0    13.486985     19.000703         0.095543          0.097692
# 1    19.878821     21.885088         0.103632          0.164063
#
#    concavity_mean  concave points_mean  symmetry_mean  fractal_dimension_mean  \
# 0        0.076215             0.041862       0.179702                0.062861
# 1        0.201835             0.112310       0.194277                0.062227
#
#    radius_se  texture_se  ...  concave points_se  symmetry_se  \
# 0   0.339528    1.205152  ...           0.011018     0.020340
# 1   0.994817    1.321960  ...           0.018790     0.022361
#
#    fractal_dimension_se  texture_worst  smoothness_worst  compactness_worst  \
# 0              0.003682      25.373706          0.131548           0.240817
# 1              0.004811      28.403552          0.139737           0.375064
#
#    concavity_worst  concave points_worst  symmetry_worst  \
# ...

# %% [markdown]
# Using actual class labels, each cluster is marked to represent one of them, and the accuracy of the pattern detection is assessed.

# %%
tn = 0
fn = 0
tp = 0
fp = 0
correct = 0

for i in range(1, len(labels)):
    lab = labels.iloc[i, 0]
    truth = ground_truth.iloc[i, 0]
    if lab == 1 and truth == 1:
        tn += 1
    elif lab == 1 and truth == 0:
        fn += 1
    elif lab == 0 and truth == 0:
        tp += 1
    else:
        fp += 1
    if lab != truth:
        correct += 1
        
print(tn, fn, tp, fp)
print('Recall: ' + str(tp/(tp+fp)))
print('Precision: '+ str(tp/(tp + fn)))
print('F1-score: ' + str(2 * (tp/(tp+fp)) * (tp/(tp + fn)) / ((tp/(tp+fp)) + (tp/(tp + fn)))))
# Out:
# 56 0 357 155
# Recall: 0.697265625
# Precision: 1.0
# F-score: 0.8216340621403913

# %% [markdown]
# Overall, much like the used classifiers, we felt that the data was useful for clustering. While the resulting clusters in the example given don't look as distinct by itself, subsequent data reveals a more divisive split in multi-dimensional attribute space. It is worth noting, however, that clustering results are not as accurate as those of the classifiers tested. This could be due to a number of reasons, including but not limited to a higher sensitivity to outliers (and lack of preprocessing), as well as the possibility of clusters being concave in nature (though this seems unlikely based on the visual example).
#
# Our precision was 1, which means that there were no false negatives. This is very good for this specific dataset about tumours, since the result can be used in real life. The result can be interpreted as the cluster with "malign tumours" are those with high probability of being malign and therefore have to be evaluated by a doctor.
