# %% [markdown]
# ## Alcohol and students
# Data source: https://www.kaggle.com/datasets/uciml/student-alcohol-consumption?resource=download

# %%
import pandas as pd

mat_df = pd.read_csv('student-mat.csv')
por_df = pd.read_csv('student-por.csv')

# %% [markdown]
# ## Remove unrelevant attributes and rename grade attribute

# %%
por_df = por_df.drop(columns=['school', 'famsize', 'famrel', 'famsup', 'Medu', 'Fedu', 'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'schoolsup', 'paid', 'nursery', 'internet', 'G1', 'G2'])
por_df = por_df.rename(columns = {'G3':'grade'})

mat_df = mat_df.drop(columns=['school', 'famsize', 'famrel', 'famsup', 'Medu', 'Fedu', 'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'schoolsup', 'paid', 'nursery', 'internet', 'G1', 'G2'])
mat_df = mat_df.rename(columns = {'G3':'grade'})

# %%
print(por_df)
print(mat_df)
sns.lmplot(x="age", y="failures", data=mat_df);
# Out:
#     sex  age address Pstatus  studytime  failures activities higher romantic  \
# 0     F   18       U       A          2         0         no    yes       no
# 1     F   17       U       T          2         0         no    yes       no
# 2     F   15       U       T          2         0         no    yes       no
# 3     F   15       U       T          3         0        yes    yes      yes
# 4     F   16       U       T          2         0         no    yes       no
# ..   ..  ...     ...     ...        ...       ...        ...    ...      ...
# 644   F   19       R       T          3         1        yes    yes       no
# 645   F   18       U       T          2         0         no    yes       no
# 646   F   18       U       T          2         0        yes    yes       no
# 647   M   17       U       T          1         0         no    yes       no
# 648   M   18       R       T          1         0         no    yes       no
#
# ...

# %%
mat_df.corr()
# Out:
#                 age  studytime  failures  freetime     goout      Dalc  \
# age        1.000000  -0.004140  0.243665  0.016434  0.126964  0.131125
# studytime -0.004140   1.000000 -0.173563 -0.143198 -0.063904 -0.196019
# failures   0.243665  -0.173563  1.000000  0.091987  0.124561  0.136047
# freetime   0.016434  -0.143198  0.091987  1.000000  0.285019  0.209001
# goout      0.126964  -0.063904  0.124561  0.285019  1.000000  0.266994
# Dalc       0.131125  -0.196019  0.136047  0.209001  0.266994  1.000000
# Walc       0.117276  -0.253785  0.141962  0.147822  0.420386  0.647544
# health    -0.062187  -0.075616  0.065827  0.075733 -0.009577  0.077180
# absences   0.175230  -0.062700  0.063726 -0.058078  0.044302  0.111908
# grade     -0.161579   0.097820 -0.360415  0.011307 -0.132791 -0.054660
#
#                Walc    health  absences     grade
# age        0.117276 -0.062187  0.175230 -0.161579
# studytime -0.253785 -0.075616 -0.062700  0.097820
# ...

# %%
por_df.corr()
# Out:
#                 age  studytime  failures  freetime     goout      Dalc  \
# age        1.000000  -0.008415  0.319968 -0.004910  0.112805  0.134768
# studytime -0.008415   1.000000 -0.147441 -0.068829 -0.075442 -0.137585
# failures   0.319968  -0.147441  1.000000  0.108995  0.045078  0.105949
# freetime  -0.004910  -0.068829  0.108995  1.000000  0.346352  0.109904
# goout      0.112805  -0.075442  0.045078  0.346352  1.000000  0.245126
# Dalc       0.134768  -0.137585  0.105949  0.109904  0.245126  1.000000
# Walc       0.086357  -0.214925  0.082266  0.120244  0.388680  0.616561
# health    -0.008750  -0.056433  0.035588  0.084526 -0.015741  0.059067
# absences   0.149998  -0.118389  0.122779 -0.018716  0.085374  0.172952
# grade     -0.106505   0.249789 -0.393316 -0.122705 -0.087641 -0.204719
#
#                Walc    health  absences     grade
# age        0.086357 -0.008750  0.149998 -0.106505
# studytime -0.214925 -0.056433 -0.118389  0.249789
# ...
