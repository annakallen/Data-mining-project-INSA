# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("data.csv")
data = data.drop(columns = ['Unnamed: 32', 'id'])

# data.loc[data['diagnosis'] == "B", 'diagnosis'] = 0
# data.loc[data['diagnosis'] == "M", 'diagnosis'] = 1

# %%
# num1=np.random.normal(loc=60,scale=5,size=100)
# df1=pd.DataFrame(num1,columns=['Salary'])
# df1['Type']='EmpType1'

# num2=np.random.normal(loc=50,scale=5,size=100)
# df2=pd.DataFrame(num2,columns=['Salary'])
# df2['Type']='EmpType2'


# df=pd.concat([df1,df2],axis=0)
# Since Categorical variable 'Type' has only 2 values we will convert it into numeric (0 and 1) datatype.
df = data
df['diagnosis']=(df['diagnosis']=='M').astype(int)
df
# Out:
#      diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0            1        17.99         10.38          122.80     1001.0
# 1            1        20.57         17.77          132.90     1326.0
# 2            1        19.69         21.25          130.00     1203.0
# 3            1        11.42         20.38           77.58      386.1
# 4            1        20.29         14.34          135.10     1297.0
# ..         ...          ...           ...             ...        ...
# 564          1        21.56         22.39          142.00     1479.0
# 565          1        20.13         28.25          131.20     1261.0
# 566          1        16.60         28.08          108.30      858.1
# 567          1        20.60         29.33          140.10     1265.0
# 568          0         7.76         24.54           47.92      181.0
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# ...

# %%
data.corr()

# from pandas import factorize
# df = data
# labels, categories = factorize(df["diagnosis"])
# df["labels"] = labels
# abs(df["diagnosis"].corr(df["labels"]))
# Out:
#                          diagnosis  radius_mean  texture_mean  perimeter_mean  \
# diagnosis                 1.000000     0.730029      0.415185        0.742636
# radius_mean               0.730029     1.000000      0.323782        0.997855
# texture_mean              0.415185     0.323782      1.000000        0.329533
# perimeter_mean            0.742636     0.997855      0.329533        1.000000
# area_mean                 0.708984     0.987357      0.321086        0.986507
# smoothness_mean           0.358560     0.170581     -0.023389        0.207278
# compactness_mean          0.596534     0.506124      0.236702        0.556936
# concavity_mean            0.696360     0.676764      0.302418        0.716136
# concave points_mean       0.776614     0.822529      0.293464        0.850977
# symmetry_mean             0.330499     0.147741      0.071401        0.183027
# fractal_dimension_mean   -0.012838    -0.311631     -0.076437       -0.261477
# ...

# %%
old_data = data
data = data.drop(columns = ['fractal_dimension_mean', 'texture_se', 'smoothness_se', 'symmetry_se', 'fractal_dimension_se', 'diagnosis'])
data = data.drop(columns = ['fractal_dimension_worst', 'symmetry_worst', 'smoothness_worst', 'texture_worst', 'symmetry_mean'])

# %%
from sklearn import cluster
k_means = cluster.KMeans(n_clusters=2, max_iter=20000, random_state=1)
k_means.fit(data)

labels = pd.DataFrame(k_means.labels_,columns=['Cluster ID'])
result = pd.concat((data,labels), axis=1)
result.plot.scatter(x='radius_worst',y='smoothness_mean',c='Cluster ID', colormap='jet')

# %%
centroids = k_means.cluster_centers_
pd.DataFrame(centroids,columns=data.columns)
# Out:
#    radius_mean  texture_mean  perimeter_mean    area_mean  smoothness_mean  \
# 0    19.379924     21.694580      128.231298  1185.929771         0.101295
# 1    12.556299     18.570365       81.123470   496.061872         0.094884
#
#    compactness_mean  concavity_mean  concave points_mean  radius_se  \
# 0          0.148613        0.176939             0.100699   0.742804
# 1          0.091100        0.062438             0.033433   0.304191
#
#    perimeter_se    area_se  compactness_se  concavity_se  concave points_se  \
# 0      5.250580  95.678168        0.032177      0.042420           0.015674
# 1      2.152881  23.785292        0.023475      0.028746           0.010636
#
#    radius_worst  perimeter_worst   area_worst  compactness_worst  \
# 0     23.709466       158.496183  1753.022901           0.357758
# 1     14.043902        91.937511   619.647945           0.223312
#
#    concavity_worst  concave points_worst
# 0         0.449306              0.192431
# ...

# %%
tn = 0
fn = 0
tp = 0
fp = 0

for i in range(1, len(labels)):
    lab = labels.iloc[i, 0]
    truth = old_data.iloc[i, 0]
    if lab == 1 and truth == 0:
        tn += 1
    elif lab == 1 and truth == 1:
        fn += 1
    elif lab == 0 and truth == 1:
        tp += 1
    else:
        fp += 1
    if lab != truth:
        correct += 1
        
print(tn, fn, tp, fp)
print('Recall: ' + str(tp/(tp+fp)))
print('Precision: '+ str(tp/(tp + fn)))
print('F-score: ' + str(2 * (tp/(tp+fp)) * (tp/(tp + fn)) / ((tp/(tp+fp)) + (tp/(tp + fn)))))
# Out:
# 356 82 129 1
# Recall: 0.9923076923076923
# Precision: 0.6113744075829384
# F-score: 0.7565982404692082

# %%
b = []
m = []
for i in range(len(labels)):
    if old_data.iloc[i, 0] == 1:
        m.append(old_data.iloc[i, 10])
    else:
        b.append(old_data.iloc[i, 10])

# %%
print(len(b))
print(len(m))
sorted_b = b.sort()
sorted_m = m.sort()

xb = [1 for i in range(len(b))]
xm = [1 for i in range(len(m))]
# Out:
# 357
# 212

# %%
import matplotlib.pyplot as plt

plt.plot(sorted_b, xb)
# plt.plot(sorted_m, xm, 'x')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-204-4c75d59fdc40> in <module>
#       1 import matplotlib.pyplot as plt
#       2
# ----> 3 plt.plot(sorted_b, xb)
#       4 # plt.plot(sorted_m, xm, 'x')
#       5
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2794     return gca().plot(
#    2795         *args, scalex=scalex, scaley=scaley, **({"data": data} if data
# -> 2796         is not None else {}), **kwargs)
#    2797
#    2798
#
# ~\anaconda3\lib\site-packages\matplotlib\axes\_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1663         """
#    1664         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D._alias_map)
# -> 1665         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1666         for line in lines:
#    1667             self.add_line(line)
#
# ...

# %%
print(max(m))
print(min(m))
print(max(b))
print(min(b))
# Out:
# 0.09744
# 0.049960000000000004
# 0.09575
# 0.05185
